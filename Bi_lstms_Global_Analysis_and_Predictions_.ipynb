# %% [markdown]
# ## Importing all the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
keras = tf.keras
from sklearn.preprocessing import MinMaxScaler
import plotly.graph_objects as go
from keras.layers import GRU, LSTM, Activation
from keras.preprocessing.sequence import pad_sequences
physical_devices = tf.config.experimental.list_physical_devices('GPU')
from sklearn.model_selection import train_test_split
import numpy as np
# tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Helper Functions

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

class ResetStatesCallback(keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs):
        self.model.reset_states()

# %% [markdown]
# ## Importing CoronaVirus Cases Data

# %%
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %% [markdown]
# ## Data Pre Processing

# %% [markdown]
# ### Confirmed Data

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  8/26/20  8/27/20  8/28/20
# 0            NaN    Afghanistan  33.93911  ...    38113    38129    38140
# 1            NaN        Albania  41.15330  ...     8927     9083     9195
# 2            NaN        Algeria  28.03390  ...    42619    43016    43403
# 3            NaN        Andorra  42.50630  ...     1098     1098     1124
# 4            NaN         Angola -11.20270  ...     2332     2415     2471
#
# [5 rows x 224 columns]

# %%
death_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  8/26/20  8/27/20  8/28/20
# 0            NaN    Afghanistan  33.93911  ...     1401     1401     1402
# 1            NaN        Albania  41.15330  ...      263      266      271
# 2            NaN        Algeria  28.03390  ...     1465     1475     1483
# 3            NaN        Andorra  42.50630  ...       53       53       53
# 4            NaN         Angola -11.20270  ...      103      105      106
#
# [5 rows x 224 columns]

# %%
recovered_df.head()
# Out:
#   Province/State Country/Region       Lat  ...  8/26/20  8/27/20  8/28/20
# 0            NaN    Afghanistan  33.93911  ...    29042    29046    29059
# 1            NaN        Albania  41.15330  ...     4633     4791     4923
# 2            NaN        Algeria  28.03390  ...    29886    30157    30436
# 3            NaN        Andorra  42.50630  ...      893      893      902
# 4            NaN         Angola -11.20270  ...      977     1335     1028
#
# [5 rows x 224 columns]

# %%
confirmed_df = confirmed_df.iloc[:, 4:]
confirmed_df = confirmed_df.sum(axis=0)
confirmed_df.index = pd.to_datetime(confirmed_df.index).strftime('%Y-%m-%d')
confirmed_df = pd.DataFrame(confirmed_df)

# %% [markdown]
# ### Death Data

# %%
death_df = death_df.iloc[:, 4:]
death_df = death_df.sum(axis=0)
death_df.index = pd.to_datetime(death_df.index).strftime('%Y-%m-%d')
death_df = pd.DataFrame(death_df)

# %% [markdown]
# ### Recovered Data

# %%
recovered_df = recovered_df.iloc[:, 4:]
recovered_df = recovered_df.sum(axis=0)
recovered_df.index = pd.to_datetime(recovered_df.index).strftime('%Y-%m-%d')
recovered_df = pd.DataFrame(recovered_df)

# %% [markdown]
# # Overall Corona Cases

# %% [markdown]
# # Scaling Data

# %% [markdown]
# ### Confirmed Cases Data

# %%
scaler_confirm = MinMaxScaler()
scaler_confirm = scaler_confirm.fit(confirmed_df)
train_confirm = scaler_confirm.fit_transform(confirmed_df)
train_confirm = pd.DataFrame(train_confirm)

# %% [markdown]
# ### Death Cases Data

# %%
scaler_death = MinMaxScaler()
scaler_death = scaler_death.fit(death_df)
train_death = scaler_death.transform(death_df)
train_death = pd.DataFrame(train_death)

# %% [markdown]
# ### Recovered Data

# %%
scaler_recovered = MinMaxScaler()
scaler_recovered = scaler_recovered.fit(recovered_df)
train_recovered = scaler_recovered.fit_transform(recovered_df)
train_recovered = pd.DataFrame(train_recovered)

# %% [markdown]
# ## Preparing Data For Time Series Analysis Using LSTM

# %%
time_steps = 1
X_train_confirm, y_train_confirm = create_dataset(train_confirm, train_confirm, time_steps)
X_test_confirm, y_test_confirm = create_dataset(train_confirm, train_confirm, time_steps)
X_train_death, y_train_death = create_dataset(train_death, train_death, time_steps)
X_train_recovered, y_train_recovered = create_dataset(train_recovered, train_recovered, time_steps)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ## Model for Confirmed Cases

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

confirm_model = keras.Sequential()
confirm_model.add(keras.layers.Bidirectional(LSTM(units=128,input_shape=(X_train_confirm.shape[1], X_train_confirm.shape[2]),return_sequences = True)))
confirm_model.add(keras.layers.Bidirectional(LSTM(units=128,return_sequences = True)))
confirm_model.add(keras.layers.Bidirectional(LSTM(units=128,return_sequences = True)))
confirm_model.add(keras.layers.Bidirectional(LSTM(units=128)))
confirm_model.add(keras.layers.Dropout(rate=0.2))
confirm_model.add(keras.layers.Dense(units=1))
confirm_model.add(Activation('softmax'))
confirm_model.compile(loss='categorical_crossentropy', optimizer='rmsprop',metrics=['accuracy']) 

reset_states = ResetStatesCallback()
# print(confirm_model.summary())
print("Training ...")
confirm_model.fit(X_train_confirm, y_train_confirm,epochs=500,batch_size=16,shuffle=False,callbacks = [reset_states],verbose = 0)
print("Validating ...")
loss,accuracy = confirm_model.evaluate(X_test_confirm,y_test_confirm,batch_size=16, verbose=1)
print("Loss:  ", loss)
print("Accuracy:  ", accuracy)
# Out:
# Training ...
# Validating ...
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Loss:   0.0
# Accuracy:   0.004566209856420755

# %% [markdown]
# ## Model for Death Cases

# %%
#Bidirectional(LSTM
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

death_model = keras.Sequential()
death_model.add(keras.layers.Bidirectional(LSTM(units=128,input_shape=(X_train_death.shape[1], X_train_death.shape[2]),return_sequences = True)))
death_model.add(keras.layers.Bidirectional(LSTM(units=128,return_sequences = True)))
death_model.add(keras.layers.Bidirectional(LSTM(units=128,return_sequences = True)))
death_model.add(keras.layers.Bidirectional(LSTM(units=128)))
death_model.add(keras.layers.Dropout(rate=0.2))
death_model.add(keras.layers.Dense(units=1))
death_model.add(Activation('softmax'))
death_model.compile(loss='categorical_crossentropy', optimizer='rmsprop',metrics=['accuracy'])
reset_states = ResetStatesCallback()
death_model.fit(X_train_death, y_train_death,epochs=500,batch_size=16)
# Out:
# Epoch 1/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 2/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 3/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 4/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 5/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 6/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 7/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 8/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 9/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 10/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 11/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 12/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 13/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 14/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 15/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 16/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 17/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 18/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 19/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 20/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 21/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 22/500
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 23/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 24/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 25/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 26/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 27/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 28/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 29/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 30/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 31/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 32/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 33/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 34/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 35/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 36/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 37/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 38/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 39/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 40/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 41/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 42/500
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 43/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 44/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 45/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 46/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 47/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 48/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 49/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 50/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 51/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 52/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 53/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 54/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 55/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 56/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 57/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 58/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 59/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 60/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 61/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 62/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 63/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 64/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 65/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 66/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 67/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 68/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 69/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 70/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 71/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 72/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 73/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 74/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 75/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 76/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 77/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 78/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 79/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 80/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 81/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 82/500
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 83/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 84/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 85/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 86/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 87/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 88/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 89/500
# 14/14 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 90/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 91/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 92/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 93/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 94/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 95/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 96/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 97/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 98/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 99/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 100/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 101/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 102/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 103/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 104/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 105/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 106/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 107/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 108/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 109/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 110/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 111/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 112/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 113/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 114/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 115/500
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 116/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 117/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 118/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 119/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 120/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 121/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 122/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 123/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 124/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 125/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 126/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 127/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 128/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 129/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 130/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 131/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 132/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 133/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 134/500
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 135/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 136/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 137/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 138/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 139/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 140/500
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 141/500
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 142/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 143/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 144/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 145/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 146/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 147/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 148/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 149/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 150/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 151/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 152/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 153/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 154/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 155/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 156/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 157/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 158/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 159/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 160/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 161/500
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 162/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 163/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 164/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 165/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 166/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 167/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 168/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 169/500
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 170/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 171/500
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch
500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 364/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 365/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 366/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 367/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 368/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 369/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 370/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 371/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 372/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 373/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 374/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 375/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 376/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 377/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 378/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 379/500
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 380/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 381/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 382/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 383/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 384/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 385/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 386/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 387/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 388/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 389/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 390/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 391/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 392/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 393/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 394/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 395/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 396/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 397/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 398/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 399/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 400/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 401/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 402/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 403/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 404/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 405/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 406/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 407/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 408/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 409/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 410/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 411/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 412/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 413/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 414/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 415/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 416/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 417/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 418/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 419/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 420/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 421/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 422/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 423/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 424/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 425/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 426/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 427/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 428/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 429/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 430/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 431/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 432/500
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 433/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 434/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 435/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 436/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 437/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 438/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 439/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 440/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 441/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 442/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 443/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 444/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 445/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 446/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 447/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 448/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 449/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 450/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 451/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 452/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 453/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 454/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 455/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 456/500
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 457/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 458/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 459/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 460/500
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 461/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 462/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 463/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 464/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 465/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 466/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 467/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 468/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 469/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 470/500
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 471/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 472/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 473/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 474/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 475/500
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 476/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 477/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 478/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 479/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 480/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 481/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 482/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 483/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 484/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 485/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 486/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 487/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 488/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 489/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 490/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 491/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 492/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 493/500
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 494/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 495/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 496/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 497/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 498/500
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 499/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046
# Epoch 500/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0000e+00 - accuracy: 0.0046

# %% [markdown]
# ## Predicting The Results

# %%
DAYS_TO_PREDICT = int(input('Enter Number Of Days You Want to Predict : '))
# Out:
# Enter Number Of Days You Want to Predict : 20

# %% [markdown]
# ### Predicting Results For Confirmed Cases

# %%
confirm_test_seq  = y_train_confirm[-1:]
confirm_preds = []
for _ in range(DAYS_TO_PREDICT):
    y2_confirm = confirm_test_seq.reshape((len(confirm_test_seq ), time_steps, 1))
    confirm_pred = confirm_model.predict(y2_confirm)
    confirm_preds.append(confirm_pred)
    confirm_new_seq = confirm_test_seq.flatten()
    confirm_new_seq = np.append(confirm_new_seq,[confirm_pred])
    confirm_new_seq = confirm_new_seq[-1:]
    confirm_test_seq = confirm_new_seq.reshape((len(confirm_new_seq), time_steps, 1))
    y2_confirm = confirm_test_seq
    
confirm_preds = (np.array(confirm_preds).flatten()).reshape(-1,1)
confirm_preds = scaler_confirm.inverse_transform(confirm_preds)

predicted_confirmed_index = pd.date_range(start=confirmed_df.index[-1],periods=DAYS_TO_PREDICT + 1,closed='right').strftime('%Y-%m-%d')
predicted_confirmed_cases = pd.DataFrame()
predicted_confirmed_cases['Dates'] = predicted_confirmed_index
predicted_confirmed_cases['Confirmed Cases Predictions'] = confirm_preds
predicted_confirmed_cases.set_index('Dates', inplace = True)

# %%
fig = go.Figure()
fig.update_layout(template='plotly_dark')
fig.update_xaxes(tickangle=90, showticklabels = True, type = 'category')
fig.add_trace(go.Scatter(x=predicted_confirmed_cases.index, 
                         y=predicted_confirmed_cases['Confirmed Cases Predictions'],
                         mode='lines+markers',
                         name='confirm',
                         line=dict(color='red', width=2)))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f874468b-8921-43ee-8157-5f87862ccff5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f874468b-8921-43ee-8157-5f87862ccff5")) {
#                     Plotly.newPlot(
#                         'f874468b-8921-43ee-8157-5f87862ccff5',
#                         [{"line": {"color": "red", "width": 2}, "mode": "lines+markers", "name": "confirm", "type": "scatter", "x": ["2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17"], "y": [24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinew ...

# %% [markdown]
# ### Predicting Results For Death Cases

# %%
death_test_seq  = y_train_death[-1:]
death_preds = []
for i in range(DAYS_TO_PREDICT):
    y2_death = death_test_seq.reshape((len(death_test_seq), time_steps, 1))
    death_pred = death_model.predict(y2_death)
    death_preds.append(death_pred)
    death_new_seq = death_test_seq.flatten()
    death_new_seq = np.append(death_new_seq,[death_pred])
    death_new_seq = death_new_seq[-1:]
    death_test_seq = death_new_seq.reshape((len(death_new_seq), time_steps, 1))
    y2_death = death_test_seq
    
death_preds = (np.array(death_preds).flatten()).reshape(-1,1)
death_preds = scaler_death.inverse_transform(death_preds)

predict_death_index = pd.date_range(start=death_df.index[-1],periods=DAYS_TO_PREDICT + 1,closed='right').strftime('%Y-%m-%d')
predict_death_cases = pd.DataFrame()
predict_death_cases['Dates'] = predict_death_index
predict_death_cases['Death Cases Predictions'] = death_preds
predict_death_cases.set_index('Dates', inplace = True)

# %%
fig = go.Figure()
fig.update_layout(template='plotly_dark')
fig.update_xaxes(tickangle=90, showticklabels = True, type = 'category')
fig.add_trace(go.Scatter(x=predict_death_cases.index, 
                         y=predict_death_cases['Death Cases Predictions'],
                         mode='lines+markers',
                         name='death',
                         line=dict(color='blue', width=2)))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0dffd5be-4c43-404d-b153-d22cc2fe5f89" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0dffd5be-4c43-404d-b153-d22cc2fe5f89")) {
#                     Plotly.newPlot(
#                         '0dffd5be-4c43-404d-b153-d22cc2fe5f89',
#                         [{"line": {"color": "blue", "width": 2}, "mode": "lines+markers", "name": "death", "type": "scatter", "x": ["2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17"], "y": [837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinew ...

# %% [markdown]
# ### Predicting Results For Recovered Cases

# %%
recovered_test_seq  = y_train_recovered[-1:]
recovered_preds = []
for i in range(DAYS_TO_PREDICT):
    y2_recovered = recovered_test_seq.reshape((len(recovered_test_seq), time_steps, 1))
    recovered_pred = recovered_model.predict(y2_recovered)
    recovered_preds.append(recovered_pred)
    recovered_new_seq = recovered_test_seq.flatten()
    recovered_new_seq = np.append(recovered_new_seq,[recovered_pred])
    recovered_new_seq = recovered_new_seq[-1:]
    recovered_test_seq = recovered_new_seq.reshape((len(recovered_new_seq), time_steps, 1))
    y2_recovered = recovered_test_seq
    
recovered_preds = (np.array(recovered_preds).flatten()).reshape(-1,1)
recovered_preds = scaler_recovered.inverse_transform(recovered_preds)

predict_recovered_index = pd.date_range(start=recovered_df.index[-1],periods=DAYS_TO_PREDICT + 1,closed='right').strftime('%Y-%m-%d')

predict_recovered_cases = pd.DataFrame()
predict_recovered_cases['Dates'] = predict_recovered_index
predict_recovered_cases['Recovered Cases Predictions'] = recovered_preds
predict_recovered_cases.set_index('Dates', inplace = True)

# %%
fig = go.Figure()
fig.update_layout(template='plotly_dark')
fig.update_xaxes(tickangle=90, showticklabels = True, type = 'category')
fig.add_trace(go.Scatter(x=predict_recovered_cases.index, 
                         y=predict_recovered_cases['Recovered Cases Predictions'],
                         mode='lines+markers',
                         name='recovered',
                         line=dict(color='green', width=2)))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="65a7bb44-96b9-465f-936d-8ae7b37ef4a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("65a7bb44-96b9-465f-936d-8ae7b37ef4a7")) {
#                     Plotly.newPlot(
#                         '65a7bb44-96b9-465f-936d-8ae7b37ef4a7',
#                         [{"line": {"color": "green", "width": 2}, "mode": "lines+markers", "name": "recovered", "type": "scatter", "x": ["2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17"], "y": [16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinew ...

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Historial Cases

# %%
fig = go.Figure()
fig.update_layout(template='plotly_dark')
fig.update_xaxes(tickangle=90, showticklabels = True, type = 'category')
fig.add_trace(go.Scatter(x=confirmed_df.index, 
                         y=confirmed_df[0],
                         mode='lines+markers',
                         name='confirm',
                         line=dict(color='red', width=2)))
fig.add_trace(go.Scatter(x=death_df.index, 
                         y=death_df[0],
                         mode='lines+markers',
                         name='death',
                         line=dict(color='green', width=2)))
fig.add_trace(go.Scatter(x=recovered_df.index, 
                         y=recovered_df[0],
                         mode='lines+markers',
                         name='recovered',
                         line=dict(color='blue', width=2)))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e0e990bc-f837-46a3-8aef-921638f49ed6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e0e990bc-f837-46a3-8aef-921638f49ed6")) {
#                     Plotly.newPlot(
#                         'e0e990bc-f837-46a3-8aef-921638f49ed6',
#                         [{"line": {"color": "red", "width": 2}, "mode": "lines+markers", "name": "confirm", "type": "scatter", "x": ["2020-01-22", "2020-01-23", "2020-01-24", "2020-01-25", "2020-01-26", "2020-01-27", "2020-01-28", "2020-01-29", "2020-01-30", "2020-01-31", "2020-02-01", "2020-02-02", "2020-02-03", "2020-02-04", "2020-02-05", "2020-02-06", "2020-02-07", "2020-02-08", "2020-02-09", "2020-02-10", "2020-02-11", "2020-02-12", "2020-02-13", "2020-02-14", "2020-02-15", "2020-02-16", "2020-02-17", "2020-02-18", "2020-02-19", "2020-02-20", "2020-02-21", "2020-02-22", "2020-02-23", "2020-02-24", "2020-02-25", "2020-02-26", "2020-02-27", "2020-02-28", "2020-02-29", "2020-03-01", "2020-03-02", "2020-03-03", "2020-03-04", "2020-03-05", "2020-03-06", "2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11", "2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20", "2020-03-21", "2020-03-22", "2020-03-23", "2020-03-24", "2020-03-25", "2020-03-26", "2020-03-27", "2020-03-28", "2020-03-29", "2020-03-30", "2020-03-31", "2020-04-01", "2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05", "2020-04-06", "2020-04-07", "2020-04-08", "2020-04-09", "2020-04-10", "2020-04-11", "2020-04-12", "2020-04-13", "2020-04-14", "2020-04-15", "2020-04-16", "2020-04-17", "2020-04-18", "2020-04-19", "2020-04-20", "2020-04-21", "2020-04-22", "2020-04-23", "2020-04-24", "2020-04-25", "2020-04-26", "2020-04-27", "2020-04-28", "2020-04-29", "2020-04-30", "2020-05-01", "2020-05-02", "2020-05-03", "2020-05-04", "2020-05-05", "2020-05-06", "2020-05-07", "2020-05-08", "2020-05-09", "2020-05-10", "2020-05-11", "2020-05-12", "2020-05-13", "2020-05-14", "2020-05-15", "2020-05-16", "2020-05-17", "2020-05-18", "2020-05-19", "2020-05-20", "2020-05-21", "2020-05-22", "2020-05-23", "2020-05-24", "2020-05-25", "2020-05-26", "2020-05-27", "2020-05-28", "2020-05-29", "2020-05-30", "2020-05-31", "2020-06-01", "2020-06-02", "2020-06-03", "2020-06-04", "2020-06-05", "2020-06-06", "2020-06-07", "2020-06-08", "2020-06-09", "2020-06-10", "2020-06-11", "2020-06-12", "2020-06-13", "2020-06-14", "2020-06-15", "2020-06-16", "2020-06-17", "2020-06-18", "2020-06-19", "2020-06-20", "2020-06-21", "2020-06-22", "2020-06-23", "2020-06-24", "2020-06-25", "2020-06-26", "2020-06-27", "2020-06-28", "2020-06-29", "2020-06-30", "2020-07-01", "2020-07-02", "2020-07-03", "2020-07-04", "2020-07-05", "2020-07-06", "2020-07-07", "2020-07-08", "2020-07-09", "2020-07-10", "2020-07-11", "2020-07-12", "2020-07-13", "2020-07-14", "2020-07-15", "2020-07-16", "2020-07-17", "2020-07-18", "2020-07-19", "2020-07-20", "2020-07-21", "2020-07-22", "2020-07-23", "2020-07-24", "2020-07-25", "2020-07-26", "2020-07-27", "2020-07-28", "2020-07-29", "2020-07-30", "2020-07-31", "2020-08-01", "2020-08-02", "2020-08-03", "2020-08-04", "2020-08-05", "2020-08-06", "2020-08-07", "2020-08-08", "2020-08-09", "2020-08-10", "2020-08-11", "2020-08-12", "2020-08-13", "2020-08-14", "2020-08-15", "2020-08-16", "2020-08-17", "2020-08-18", "2020-08-19", "2020-08-20", "2020-08-21", "2020-08-22", "2020-08-23", "2020-08-24", "2020-08-25", "2020-08-26", "2020-08-27", "2020-08-28"], "y": [555, 654, 941, 1434, 2118, 2927, 5578, 6166, 8234, 9926, 12038, 16787, 19887, 23898, 27643, 30802, 34395, 37129, 40159, 42768, 44810, 45228, 60381, 66908, 69050, 71234, 73269, 75151, 75651, 76211, 76840, 78601, 78981, 79545, 80398, 81375, 82735, 84120, 86013, 88395, 90373, 92958, 95273, 98030, 102025, 106036, 109994, 113950, 118965, 126679, 132481, 146825, 157857, 169014, 183683, 199562, 219214, 247116, 276706, 309026, 342393, 384630, 425787, 476680, 539549, 604085, 671663, 731267, 795997, 872475, 948663, 1030010, 1113203, 1193711, 1265377, 1338067, 1415186, 1498895, 1585483, 1672988, 1749872, 1846819, 1916464, 1986284, 2067245, 2163941, 2251672, 2325556, 2405885, 2479307, 2554750, 2631576, 2720583, 2807495, 2892296, 2965076, 3034072, 3109425, 3186589, 3270117, 3357276, ...

# %% [markdown]
# ## Predictions for every individual scenario

# %%
fig = go.Figure()
fig.update_layout(template='plotly_dark')
fig.update_xaxes(tickangle=90, showticklabels = True, type = 'category')
fig.add_trace(go.Scatter(x=predicted_confirmed_cases.index, 
                         y=predicted_confirmed_cases['Confirmed Cases Predictions'],
                         mode='lines+markers',
                         name='Confirmed Cases Predictions',
                         line=dict(color='yellow', width=2)))

fig.add_trace(go.Scatter(x=predict_death_cases.index, 
                         y=predict_death_cases['Death Cases Predictions'],
                         mode='lines+markers',
                         name='Death Cases Predictions',
                         line=dict(color='turquoise', width=2)))

fig.add_trace(go.Scatter(x=predict_recovered_cases.index, 
                         y=predict_recovered_cases['Recovered Cases Predictions'],
                         mode='lines+markers',
                         name='Recovered Cases Predictions',
                         line=dict(color='white', width=2)))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a442cede-1b5a-411e-8303-eda92f10227d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a442cede-1b5a-411e-8303-eda92f10227d")) {
#                     Plotly.newPlot(
#                         'a442cede-1b5a-411e-8303-eda92f10227d',
#                         [{"line": {"color": "yellow", "width": 2}, "mode": "lines+markers", "name": "Confirmed Cases Predictions", "type": "scatter", "x": ["2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17"], "y": [24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0, 24734448.0]}, {"line": {"color": "turquoise", "width": 2}, "mode": "lines+markers", "name": "Death Cases Predictions", "type": "scatter", "x": ["2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17"], "y": [837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375, 837123.9375]}, {"line": {"color": "white", "width": 2}, "mode": "lines+markers", "name": "Recovered Cases Predictions", "type": "scatter", "x": ["2020-08-29", "2020-08-30", "2020-08-31", "2020-09-01", "2020-09-02", "2020-09-03", "2020-09-04", "2020-09-05", "2020-09-06", "2020-09-07", "2020-09-08", "2020-09-09", "2020-09-10", "2020-09-11", "2020-09-12", "2020-09-13", "2020-09-14", "2020-09-15", "2020-09-16", "2020-09-17"], "y": [16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0, 16198166.0]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinew ...

# %% [markdown]
# ## Historical and Predicted Values

# %%
fig = go.Figure()
fig.update_layout(template='plotly_dark')
fig.update_xaxes(tickangle=90, showticklabels = True, type = 'category')
fig.add_trace(go.Scatter(x=confirmed_df.index, 
                         y=confirmed_df[0],
                         mode='lines+markers',
                         name='confirm',
                         line=dict(color='red', width=2)))

fig.add_trace(go.Scatter(x=death_df.index, 
                         y=death_df[0],
                         mode='lines+markers',
                         name='death',
                         line=dict(color='green', width=2)))

fig.add_trace(go.Scatter(x=recovered_df.index, 
                         y=recovered_df[0],
                         mode='lines+markers',
                         name='recovered',
                         line=dict(color='blue', width=2)))

fig.add_trace(go.Scatter(x=predicted_confirmed_cases.index, 
                         y=predicted_confirmed_cases['Confirmed Cases Predictions'],
                         mode='lines+markers',
                         name='Confirmed Cases Predictions',
                         line=dict(color='yellow', width=2)))

fig.add_trace(go.Scatter(x=predict_death_cases.index, 
                         y=predict_death_cases['Death Cases Predictions'],
                         mode='lines+markers',
                         name='Death Cases Predictions',
                         line=dict(color='turquoise', width=2)))

fig.add_trace(go.Scatter(x=predict_recovered_cases.index, 
                         y=predict_recovered_cases['Recovered Cases Predictions'],
                         mode='lines+markers',
                         name='Recovered Cases Predictions',
                         line=dict(color='white', width=2)))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="